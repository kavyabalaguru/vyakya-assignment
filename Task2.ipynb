# %% [markdown]
# <a href="https://colab.research.google.com/github/kavyabalaguru/vyakya-assignment/blob/main/Task2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded =files.upload()
# Out:
#      <input type="file" id="files-fe342d50-72cd-4a0a-9d68-211a45747c18" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fe342d50-72cd-4a0a-9d68-211a45747c18">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving task_input_list.json to task_input_list.json

# %%
import pandas as pd
data=pd.read_json("task_input_list.json")
data
# Out:
#                                         0
# 0                                ABC BANK
# 1                       Preferred Rewards
# 2                          P.O. Box 12345
# 3            Customer service information
# 4                   Wilmington, DE 144444
# ..                                    ...
# 210    Memo 4100390077958227 815830260521
# 211  Authorizedby your Depositor 11/27/18
# 212                           Page 5 of 6
# 213    This page intentionally left blank
# 214                           Page 6 of 6
#
# [215 rows x 1 columns]

# %%
data.rename(columns={0:'info'}, inplace=True)

# %%
df1=data[:35:]
df1
# Out:
#                                                  info
# 0                                            ABC BANK
# 1                                   Preferred Rewards
# 2                                      P.O. Box 12345
# 3                        Customer service information
# 4                               Wilmington, DE 144444
# 5                                                   0
# 6                                  ph: (555) 555-1234
# 7             TDD/TTY users only call: (800) 555-1234
# 8                               other: 1-800-555-1234
# 9                                            John Doe
# 10                                bankingservices.com
# 11                              Your Adv Plus Banking
# 12                         Preferred Rewards Platinum
# 13         for November 27, 2018 to December 24, 2018
# 14                                    Account summary
# 15             Beginning balance on November 27, 2018
# ...

# %%
df2=data[73:133]
df2
# Out:
#                                                   info
# 73              November 27, 2018 to December 24, 2018
# 74                        Deposits and other additions
# 75                                                Date
# 76                                         Description
# 77                                              Amount
# 78                                            12/03/18
# 79                                      Counter Credit
# 80                                            8,075.00
# 81                                            12/10/18
# 82                                      Counter Credit
# 83                                            9,970.00
# 84                                            12/21/18
# 85                                              PAYPAL
# 86                 DES:TRANSFER ID:1004561753452 INDN:
# 87                                                  CO
# 88                                            1,000.00
# ...

# %%
import re
df=str(data['info'])
lst = re.findall('\S+@\S+', df)
lst
# Out:
# []

# %%
df1=str(df1['info'])
r = re.compile(r'(\d{3}[-\.\s]??\d{3}[-\.\s]??\d{4}|\(\d{3}\)\s*\d{3}[-\.\s]??\d{4}|\d{3}[-\.\s]??\d{4})')
results = r.findall(df1)
results
# Out:
# ['(555) 555-1234', '(800) 555-1234', '800-555-1234']
